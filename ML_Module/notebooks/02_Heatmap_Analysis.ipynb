# %% [markdown]
# # 02. Heatmap & Correlation Analysis
# Visualizing feature relationships using Seaborn.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../datasets/processed_data.csv")

plt.figure(figsize=(10, 8))
corr_matrix = df.corr()

# Plot Heatmap
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.savefig("../graphs/correlation_heatmap.png")
plt.show()

print("Top features correlated with High_Performer:")
print(corr_matrix['High_Performer'].sort_values(ascending=False))
# Out:
# Top features correlated with High_Performer:
# High_Performer        1.000000
# Tasks_Completed       0.072008
# Weekly_Hours          0.031002
# Salary                0.003432
# Department_Encoded   -0.017449
# Age                  -0.023742
# Experience           -0.042032
# Gender_Encoded       -0.046321
# Name: High_Performer, dtype: float64
